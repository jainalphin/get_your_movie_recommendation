# %% [markdown]
# # Extracting features of 2018 movies from Wikipedia

# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0,skiprows=[46,47])[5]

# %%
df4 = pd.read_html(link, header=0,skiprows=range(48,67))[5]

# %%
df42 = pd.read_html(link, header=0,skiprows=range(1,49))[5]
df42.rename(columns={'Opening':'Opening.1','Opening.1':'Opening'},inplace=True)
cols=['Opening','Opening.1','Title','Production company','Cast and crew','Ref.']
df43=df42[cols]
df43
# Out:
#      Opening  Opening.1                              Title  \
# 0   DECEMBER          7                Mary Queen of Scots
# 1   DECEMBER          7                        Ben Is Back
# 2   DECEMBER         14  Spider-Man: Into the Spider-Verse
# 3   DECEMBER         14                     Mortal Engines
# 4   DECEMBER         14                           The Mule
# 5   DECEMBER         14         If Beale Street Could Talk
# 6   DECEMBER         19               Mary Poppins Returns
# 7   DECEMBER         21                            Aquaman
# 8   DECEMBER         21                          Bumblebee
# 9   DECEMBER         21                  Welcome to Marwen
# 10  DECEMBER         21                         Second Act
# 11  DECEMBER         21                           Cold War
# 12  DECEMBER         25                    Holmes & Watson
# 13  DECEMBER         25                               Vice
# 14  DECEMBER         25                On the Basis of Sex
# ...

# %%
df4.drop('Unnamed: 6',axis=1,inplace=True)
df4=df4.append(df43,ignore_index=True)
df4
# Out:
#      Opening  Opening.1                       Title  \
# 0    OCTOBER          2            Power of the Air
# 1    OCTOBER          5                       Venom
# 2    OCTOBER          5              A Star Is Born
# 3    OCTOBER          5             The Hate U Give
# 4    OCTOBER         10            The Happy Prince
# ..       ...        ...                         ...
# 59  DECEMBER         25             Holmes & Watson
# 60  DECEMBER         25                        Vice
# 61  DECEMBER         25         On the Basis of Sex
# 62  DECEMBER         25                   Destroyer
# 63  DECEMBER         28  Black Mirror: Bandersnatch
#
#                               Production company  \
# 0                            Five & Two Pictures
# 1       Columbia Pictures / Marvel Entertainment
# 2                          Warner Bros. Pictures
# 3           20th Century Fox / Fox 2000 Pictures
# 4                         Sony Pictures Classics
# ...

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 261  DECEMBER         25             Holmes & Watson
# 262  DECEMBER         25                        Vice
# 263  DECEMBER         25         On the Basis of Sex
# 264  DECEMBER         25                   Destroyer
# 265  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
df2=df.copy()

# %%
df2['Title']=df2['Title'].str.replace(': ',':')

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '113096a0c7058d06583090da3f850090'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    try:
        movie_id = result[0].id
    except Exception as e:
        return np.NaN
    
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        return np.NaN

# %%
df2['genres'] = df2['Title'].map(lambda x: get_genre(x))

# %%
df2
# Out:
#       Opening  Opening.1                      Title  \
# 0     JANUARY          5     Insidious:The Last Key
# 1     JANUARY          5           The Strange Ones
# 2     JANUARY          5                   Stratton
# 3     JANUARY         10              Sweet Country
# 4     JANUARY         12               The Commuter
# ..        ...        ...                        ...
# 261  DECEMBER         25            Holmes & Watson
# 262  DECEMBER         25                       Vice
# 263  DECEMBER         25        On the Basis of Sex
# 264  DECEMBER         25                  Destroyer
# 265  DECEMBER         28  Black Mirror:Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ...

# %%
df2.isna().sum()
# Out:
# Opening                0
# Opening.1              0
# Title                  0
# Production company     0
# Cast and crew          0
# Ref.                   1
# genres                24
# dtype: int64

# %%
df_2018 =df2[['Title','Cast and crew','genres']]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
         return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name']=df_2018['Cast and crew'].map(lambda x:get_director(x))
# Out:
# <ipython-input-16-0f2eefe5f9ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name']=df_2018['Cast and crew'].map(lambda x:get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name']=df_2018['Cast and crew'].map(lambda x:get_actor1(x))
# Out:
# <ipython-input-18-38faee977ba0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name']=df_2018['Cast and crew'].map(lambda x:get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.nan
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name']=df_2018['Cast and crew'].map(lambda x:get_actor2(x))
# Out:
# <ipython-input-20-f70b877e3c5e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name']=df_2018['Cast and crew'].map(lambda x:get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                          Title  \
# 0       Insidious:The Last Key
# 1             The Strange Ones
# 2                     Stratton
# 3                Sweet Country
# 4                 The Commuter
# ..                         ...
# 261            Holmes & Watson
# 262                       Vice
# 263        On the Basis of Sex
# 264                  Destroyer
# 265  Black Mirror:Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 261  Etan Cohen (director/screenplay); Will Ferrell...
# 262  Adam McKay (director/screenplay); Christian Ba...
# 263  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')
new_df18['genres'] = new_df18['genres'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' '\
                + new_df18['actor_2_name'] + ' '\
                + new_df18['actor_3_name'] + ' '\
                + new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 261          Etan Cohen     Will Ferrell          John C. Reilly
# 262          Adam McKay   Christian Bale               Amy Adams
# 263          Mimi Leder   Felicity Jones            Armie Hammer
# 264        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 265         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                          genres  \
# 0    Leigh Whannell         Mystery Horror Thriller
# 1     Emily Althaus                  Thriller Drama
# ...

# %% [markdown]
# # Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df1['Opening']=df1['Opening'].replace(np.NaN,'January')

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#       Opening  Opening.1             Title  \
# 0     January          4       Escape Room
# 1     January          4        Rust Creek
# 2     January          4  American Hangman
# 3     January         11  A Dog's Way Home
# 4     January         11        The Upside
# ..        ...        ...               ...
# 236  December         25      Little Women
# 237  December         25              1917
# 238  December         25        Just Mercy
# 239  December         27          Clemency
# 240  December         27        Apparition
#
#                                     Production company  \
# 0                                    Columbia Pictures
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]
df_2019
# Out:
#                 Title                                      Cast and crew  \
# 0         Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1          Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2    American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3    A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4          The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                ...                                                ...
# 236      Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 237              1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 238        Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 239          Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
# 240        Apparition  Waymon Boone (director/screenplay); Mena Suvar...
#
#                                        genres
# ...

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-43-a433a4faa834>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-45-eee71c5586b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-47-48d0aadc78c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      1
# actor_3_name     16
# genres            2
# movie_title       0
# dtype: int64

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')
new_df19['genres'] = new_df19['genres'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' \
                    + new_df19['actor_2_name'] + ' '\
                    + new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#              director_name         actor_1_name          actor_2_name  \
# 0             Adam Robitel       Taylor Russell          Logan Miller
# 1              Jen McGowan    Hermione Corfield           Jay Paulson
# 2        Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3     Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4              Neil Burger       Bryan Cranston            Kevin Hart
# ..                     ...                  ...                   ...
# 236           Greta Gerwig        Saoirse Ronan           Emma Watson
# 237             Sam Mendes        George MacKay  Dean-Charles Chapman
# 238  Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 239        Chinonye Chukwu        Alfre Woodard        Wendell Pierce
# 240           Waymon Boone          Mena Suvari          Kevin Pollak
#
#          actor_3_name                                    genres  \
# ...

# %%
new_df19.to_csv('../clean data/2019.csv')
new_df18.to_csv('../clean data/2018.csv')

# %%
my_df = new_df18.append(new_df19,ignore_index=True)

# %%
old_df = pd.read_csv('../clean data/new_data.csv')

# %%
old_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
my_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.to_csv('../clean data/final_data.csv',index=False)
